# %% [markdown]
# <a href="https://colab.research.google.com/github/samarawwleticia/estudo_python/blob/main/analise_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #INTRODUÇÃO
#
# Essa é uma análise de dados sobre a correlação de diversos fatores com a carreira de um indivíduo na área de TI. Aprendemos a utilizar diversas ferramentas disponibilizadas pela linguagem python para analisar esses dados, como pandas, numpy, matplotlib e spicy stats.

# %% [markdown]
# #Uso da biblioteca Pandas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
dados = pd.read_excel('/content/drive/MyDrive/Analise de Dados PrograMaria/planilha_modulo2.xlsx')

# %% [markdown]
# # Repetindo análise de excel

# %%
dados[dados['GENERO']=='Feminino']
# Out:
#                                     ID  IDADE FAIXA IDADE    GENERO  \
# 4     zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49  Feminino
# 5     zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34  Feminino
# 7     zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34  Feminino
# 9     zxc3d314cn1c2ovmzxc34ha7nkw1na3j    NaN         55+  Feminino
# 10    zwy34gktg0tfjq2ttjvazwy34gg3g49i   25.0       25-29  Feminino
# ...                                ...    ...         ...       ...
# 4248  070o4zayoboztox764qu070o4zafbqrd   27.0       25-29  Feminino
# 4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34  Feminino
# 4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29  Feminino
# 4259  03n2lq8st9zobnowu3w03n2lqi0flz2w   28.0       25-29  Feminino
# 4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34  Feminino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 4            Branca  Não  Não acredito que minha experiência profissiona...
# 5             Parda  Não  Não acredito que minha experiência profissiona...
# 7            Branca  Não  Não acredito que minha experiência profissiona...
# 9             Parda  Não  Não acredito que minha experiência profissiona...
# 10            Parda  Não  Não acredito que minha experiência profissiona...
# ...             ...  ...                                                ...
# 4248         Branca  Não  Não acredito que minha experiência profissiona...
# 4251          Preta  Não  Não acredito que minha experiência profissiona...
# 4258         Branca  Não  Sim, acredito que a minha a experiência profis...
# 4259         Branca  Não  Sim, acredito que a minha a experiência profis...
# 4267         Branca  Não  Não acredito que minha experiência profissiona...
#
#       PREJUDICA?                              ASPECTOS_PREJUDICADOS  \
# 4          False                                                NaN
# 5          False                                                NaN
# 7          False                                                NaN
# 9          False                                                NaN
# 10         False                                                NaN
# ...          ...                                                ...
# 4248       False                                                NaN
# 4251       False                                                NaN
# 4258        True  Senioridade das vagas recebidas em relação à s...
# 4259        True  Relação com outros membros da empresa, em mome...
# 4267       False                                                NaN
#
#       VIVE_NO_BRASIL  ...                           SETOR  \
# 4               True  ...                   Setor Público
# 5               True  ...                        Educação
# 7               True  ...  Tecnologia/Fábrica de Software
# 9               True  ...                        Educação
# 10              True  ...                          Varejo
# ...              ...  ...                             ...
# 4248            True  ...              Finanças ou Bancos
# 4251            True  ...              Finanças ou Bancos
# 4258            True  ...                             NaN
# 4259            True  ...              Finanças ou Bancos
# 4267            True  ...             Área de Consultoria
#
#      NUMERO DE FUNCIONARIOS GESTOR?       CARGO COMO GESTOR  \
# 4              de 101 a 500   False                     NaN
# 5            Acima de 3.000   False                     NaN
# 7                 de 6 a 10   False                     NaN
# 9            Acima de 3.000   False                     NaN
# 10             de 101 a 500   False                     NaN
# ...                     ...     ...                     ...
# 4248           de 101 a 500   False                     NaN
# 4251       de 1.001 a 3.000   False                     NaN
# 4258                    NaN     NaN                     NaN
# 4259         Acima de 3.000    True  Supervisor/Coordenador
# 4267            de 51 a 100   False                     NaN
#
#                                             CARGO ATUAL   NIVEL  \
# 4     Desenvolvedor/ Engenheiro de Software/ Analist...   Pleno
# 5                                             Professor   Pleno
# 7     Desenvolvedor/ Engenheiro de Software/ Analist...  Júnior
# 9                                             Professor   Pleno
# 10                            Analista de BI/BI Analyst  Júnior
# ...                                                 ...     ...
# 4248                  Cientista de Dados/Data Scientist   Pleno
# 4251  Engenheiro de Dados/Arquiteto de Dados/Data En...   Pleno
# 4258                                                NaN     NaN
# 4259                                                NaN     NaN
# 4267  Engenheiro de Dados/Arquiteto de Dados/Data En...   Pleno
#
#           NOVO NÍVEL                    FAIXA SALARIAL  \
# 4              Pleno    de R$ 6.001/mês a R$ 8.000/mês
# 5              Pleno    de R$ 2.001/mês a R$ 3.000/mês
# 7             Júnior    de R$ 2.001/mês a R$ 3.000/mês
# 9              Pleno   de R$ 8.001/mês a R$ 12.000/mês
# 10            Júnior    de R$ 3.001/mês a R$ 4.000/mês
# ...              ...                               ...
# 4248           Pleno    de R$ 4.001/mês a R$ 6.000/mês
# 4251           Pleno    de R$ 4.001/mês a R$ 6.000/mês
# 4258             NaN                               NaN
# 4259  Pessoa Gestora  de R$ 20.001/mês a R$ 25.000/mês
# 4267           Pleno    de R$ 3.001/mês a R$ 4.000/mês
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 4                Não tenho experiência na área de dados
# 5                Não tenho experiência na área de dados
# 7                                        Menos de 1 ano
# 9                                       Mais de 10 anos
# 10                                       Menos de 1 ano
# ...                                                 ...
# 4248                                      de 1 a 2 anos
# 4251                                     Menos de 1 ano
# 4258                                                NaN
# 4259                                      de 4 a 6 anos
# 4267                                      de 1 a 2 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?
# 4                                       Mais de 10 anos
# 5     Não tive experiência na área de TI/Engenharia ...
# 7                                        Menos de 1 ano
# 9     Não tive experiência na área de TI/Engenharia ...
# 10    Não tive experiência na área de TI/Engenharia ...
# ...                                                 ...
# 4248  Não tive experiência na área de TI/Engenharia ...
# 4251                                     Menos de 1 ano
# 4258                                                NaN
# 4259  Não tive experiência na área de TI/Engenharia ...
# 4267  Não tive experiência na área de TI/Engenharia ...
#
# [1056 rows x 29 columns]

# %%
dados[dados['GENERO']!='Masculino']
# Out:
#                                     ID  IDADE FAIXA IDADE    GENERO  \
# 4     zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49  Feminino
# 5     zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34  Feminino
# 7     zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34  Feminino
# 9     zxc3d314cn1c2ovmzxc34ha7nkw1na3j    NaN         55+  Feminino
# 10    zwy34gktg0tfjq2ttjvazwy34gg3g49i   25.0       25-29  Feminino
# ...                                ...    ...         ...       ...
# 4248  070o4zayoboztox764qu070o4zafbqrd   27.0       25-29  Feminino
# 4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34  Feminino
# 4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29  Feminino
# 4259  03n2lq8st9zobnowu3w03n2lqi0flz2w   28.0       25-29  Feminino
# 4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34  Feminino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 4            Branca  Não  Não acredito que minha experiência profissiona...
# 5             Parda  Não  Não acredito que minha experiência profissiona...
# 7            Branca  Não  Não acredito que minha experiência profissiona...
# 9             Parda  Não  Não acredito que minha experiência profissiona...
# 10            Parda  Não  Não acredito que minha experiência profissiona...
# ...             ...  ...                                                ...
# 4248         Branca  Não  Não acredito que minha experiência profissiona...
# 4251          Preta  Não  Não acredito que minha experiência profissiona...
# 4258         Branca  Não  Sim, acredito que a minha a experiência profis...
# 4259         Branca  Não  Sim, acredito que a minha a experiência profis...
# 4267         Branca  Não  Não acredito que minha experiência profissiona...
#
#       PREJUDICA?                              ASPECTOS_PREJUDICADOS  \
# 4          False                                                NaN
# 5          False                                                NaN
# 7          False                                                NaN
# 9          False                                                NaN
# 10         False                                                NaN
# ...          ...                                                ...
# 4248       False                                                NaN
# 4251       False                                                NaN
# 4258        True  Senioridade das vagas recebidas em relação à s...
# 4259        True  Relação com outros membros da empresa, em mome...
# 4267       False                                                NaN
#
#       VIVE_NO_BRASIL  ...                           SETOR  \
# 4               True  ...                   Setor Público
# 5               True  ...                        Educação
# 7               True  ...  Tecnologia/Fábrica de Software
# 9               True  ...                        Educação
# 10              True  ...                          Varejo
# ...              ...  ...                             ...
# 4248            True  ...              Finanças ou Bancos
# 4251            True  ...              Finanças ou Bancos
# 4258            True  ...                             NaN
# 4259            True  ...              Finanças ou Bancos
# 4267            True  ...             Área de Consultoria
#
#      NUMERO DE FUNCIONARIOS GESTOR?       CARGO COMO GESTOR  \
# 4              de 101 a 500   False                     NaN
# 5            Acima de 3.000   False                     NaN
# 7                 de 6 a 10   False                     NaN
# 9            Acima de 3.000   False                     NaN
# 10             de 101 a 500   False                     NaN
# ...                     ...     ...                     ...
# 4248           de 101 a 500   False                     NaN
# 4251       de 1.001 a 3.000   False                     NaN
# 4258                    NaN     NaN                     NaN
# 4259         Acima de 3.000    True  Supervisor/Coordenador
# 4267            de 51 a 100   False                     NaN
#
#                                             CARGO ATUAL   NIVEL  \
# 4     Desenvolvedor/ Engenheiro de Software/ Analist...   Pleno
# 5                                             Professor   Pleno
# 7     Desenvolvedor/ Engenheiro de Software/ Analist...  Júnior
# 9                                             Professor   Pleno
# 10                            Analista de BI/BI Analyst  Júnior
# ...                                                 ...     ...
# 4248                  Cientista de Dados/Data Scientist   Pleno
# 4251  Engenheiro de Dados/Arquiteto de Dados/Data En...   Pleno
# 4258                                                NaN     NaN
# 4259                                                NaN     NaN
# 4267  Engenheiro de Dados/Arquiteto de Dados/Data En...   Pleno
#
#           NOVO NÍVEL                    FAIXA SALARIAL  \
# 4              Pleno    de R$ 6.001/mês a R$ 8.000/mês
# 5              Pleno    de R$ 2.001/mês a R$ 3.000/mês
# 7             Júnior    de R$ 2.001/mês a R$ 3.000/mês
# 9              Pleno   de R$ 8.001/mês a R$ 12.000/mês
# 10            Júnior    de R$ 3.001/mês a R$ 4.000/mês
# ...              ...                               ...
# 4248           Pleno    de R$ 4.001/mês a R$ 6.000/mês
# 4251           Pleno    de R$ 4.001/mês a R$ 6.000/mês
# 4258             NaN                               NaN
# 4259  Pessoa Gestora  de R$ 20.001/mês a R$ 25.000/mês
# 4267           Pleno    de R$ 3.001/mês a R$ 4.000/mês
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 4                Não tenho experiência na área de dados
# 5                Não tenho experiência na área de dados
# 7                                        Menos de 1 ano
# 9                                       Mais de 10 anos
# 10                                       Menos de 1 ano
# ...                                                 ...
# 4248                                      de 1 a 2 anos
# 4251                                     Menos de 1 ano
# 4258                                                NaN
# 4259                                      de 4 a 6 anos
# 4267                                      de 1 a 2 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?
# 4                                       Mais de 10 anos
# 5     Não tive experiência na área de TI/Engenharia ...
# 7                                        Menos de 1 ano
# 9     Não tive experiência na área de TI/Engenharia ...
# 10    Não tive experiência na área de TI/Engenharia ...
# ...                                                 ...
# 4248  Não tive experiência na área de TI/Engenharia ...
# 4251                                     Menos de 1 ano
# 4258                                                NaN
# 4259  Não tive experiência na área de TI/Engenharia ...
# 4267  Não tive experiência na área de TI/Engenharia ...
#
# [1077 rows x 29 columns]

# %%
dados[dados['GENERO'].str.contains('não', na=False)]
# Out:
#                                     ID  IDADE FAIXA IDADE  \
# 562   vhuw8xnpbmj6oh20xovhuwcbdl4a12ni   29.0       25-29
# 1528  n2ktdn33istvlu1ha4v3kn2ktdn1rsp1    NaN         55+
# 1913  k3as6jdh3w4jf4ztsw4kpkk3as6jdy19   30.0       30-34
# 1925  jzppdwep2kpisqjjzppdh304v83cj7eu    NaN       17-21
# 2554  f5l206z0hr9uh3nz2iiff5l206c0g10o   20.0       17-21
# 3090  a6ugmsw7s8hu5aa6uglio5apj74fam9o   26.0       25-29
# 3357  7q0icczxn0l3a894cbx7q0icczjyud0n   29.0       25-29
# 3493  6m8haop6lxnaizpwij6m8haopiax98jg   25.0       25-29
# 3610  5mloglozmr0r715mntaxbt6xy8b5olmb   30.0       30-34
# 4171  0rksyxnqhn13nwytwi6y0rkssx6jmodf   26.0       25-29
# 4200  0liu228yff8fnm3zeuahsx0liu228y07   28.0       25-29
# 4227  0eqzo5w2l5wizswvwywt8h0eqzo5yucv   28.0       25-29
#
#                     GENERO        COR/RACA/ETNIA                   PCD  \
# 562   Prefiro não informar                 Parda                   Não
# 1528  Prefiro não informar              Indígena  Prefiro não informar
# 1913  Prefiro não informar  Prefiro não informar                   Não
# 1925  Prefiro não informar  Prefiro não informar  Prefiro não informar
# 2554  Prefiro não informar  Prefiro não informar                   Não
# 3090  Prefiro não informar                 Parda                   Não
# 3357  Prefiro não informar                 Preta                   Não
# 3493  Prefiro não informar                Branca                   Não
# 3610  Prefiro não informar                Branca                   Não
# 4171  Prefiro não informar                Branca                   Não
# 4200  Prefiro não informar                 Outra                   Não
# 4227  Prefiro não informar                 Preta                   Não
#
#                    EXPERIENCIA_PROFISSIONAL_PREJUDICADA  PREJUDICA?  \
# 562   Sim, acredito que a minha a experiência profis...        True
# 1528  Não acredito que minha experiência profissiona...       False
# 1913  Não acredito que minha experiência profissiona...       False
# 1925  Sim, acredito que minha experiência profission...        True
# 2554  Não acredito que minha experiência profissiona...       False
# 3090  Não acredito que minha experiência profissiona...       False
# 3357  Não acredito que minha experiência profissiona...       False
# 3493  Sim, acredito que a minha a experiência profis...        True
# 3610  Sim, acredito que a minha a experiência profis...        True
# 4171  Não acredito que minha experiência profissiona...       False
# 4200  Não acredito que minha experiência profissiona...       False
# 4227  Sim, acredito que a minha a experiência profis...        True
#
#                                   ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  ...  \
# 562   Atenção dada pelas pessoas diante das minhas o...            True  ...
# 1528                                                NaN            True  ...
# 1913                                                NaN            True  ...
# 1925  Quantidade de oportunidades de emprego/vagas r...           False  ...
# 2554                                                NaN            True  ...
# 3090                                                NaN            True  ...
# 3357                                                NaN            True  ...
# 3493  Quantidade de oportunidades de emprego/vagas r...            True  ...
# 3610               Velocidade de progressão de carreira            True  ...
# 4171                                                NaN            True  ...
# 4200                                                NaN            True  ...
# 4227  Atenção dada pelas pessoas diante das minhas o...            True  ...
#
#                                     SETOR NUMERO DE FUNCIONARIOS GESTOR?  \
# 562                                   NaN                    NaN     NaN
# 1528                        Setor Público            de 51 a 100   False
# 1913                          Outra Opção           de 101 a 500   False
# 1925                   Setor Farmaceutico               de 1 a 5   False
# 2554                        Setor Público         Acima de 3.000   False
# 3090                             Educação           de 101 a 500    True
# 3357       Tecnologia/Fábrica de Software       de 1.001 a 3.000   False
# 3493                   Finanças ou Bancos         Acima de 3.000   False
# 3610       Tecnologia/Fábrica de Software           de 101 a 500   False
# 4171                          Outra Opção       de 1.001 a 3.000   False
# 4200  Setor Imobiliário/ Construção Civil         de 501 a 1.000    True
# 4227                          Outra Opção         Acima de 3.000   False
#
#             CARGO COMO GESTOR  \
# 562                       NaN
# 1528                      NaN
# 1913                      NaN
# 1925                      NaN
# 2554                      NaN
# 3090  Team Leader/Tech Leader
# 3357                      NaN
# 3493                      NaN
# 3610                      NaN
# 4171                      NaN
# 4200  Team Leader/Tech Leader
# 4227                      NaN
#
#                                             CARGO ATUAL   NIVEL  \
# 562                                                 NaN     NaN
# 1528               Analista de Suporte/Analista Técnico  Júnior
# 1913                     Analista de Dados/Data Analyst   Pleno
# 1925                                        Outra Opção  Júnior
# 2554                  Cientista de Dados/Data Scientist  Júnior
# 3090                                                NaN     NaN
# 3357  Engenheiro de Dados/Arquiteto de Dados/Data En...  Júnior
# 3493                     Analista de Dados/Data Analyst   Pleno
# 3610  Engenheiro de Dados/Arquiteto de Dados/Data En...  Sênior
# 4171                     Analista de Dados/Data Analyst   Pleno
# 4200                                                NaN     NaN
# 4227  Product Manager/ Product Owner (PM/APM/DPM/GPM...   Pleno
#
#           NOVO NÍVEL                    FAIXA SALARIAL  \
# 562              NaN                               NaN
# 1528          Júnior             Menos de R$ 1.000/mês
# 1913           Pleno   de R$ 8.001/mês a R$ 12.000/mês
# 1925          Júnior    de R$ 2.001/mês a R$ 3.000/mês
# 2554          Júnior    de R$ 1.001/mês a R$ 2.000/mês
# 3090  Pessoa Gestora   de R$ 8.001/mês a R$ 12.000/mês
# 3357          Júnior    de R$ 6.001/mês a R$ 8.000/mês
# 3493           Pleno    de R$ 3.001/mês a R$ 4.000/mês
# 3610          Sênior   de R$ 8.001/mês a R$ 12.000/mês
# 4171           Pleno   de R$ 8.001/mês a R$ 12.000/mês
# 4200  Pessoa Gestora  de R$ 16.001/mês a R$ 20.000/mês
# 4227           Pleno    de R$ 6.001/mês a R$ 8.000/mês
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 562                                                 NaN
# 1528                                     Menos de 1 ano
# 1913                                    Mais de 10 anos
# 1925                                      de 1 a 2 anos
# 2554                                      de 1 a 2 anos
# 3090                                      de 1 a 2 anos
# 3357                                     Menos de 1 ano
# 3493                                      de 3 a 4 anos
# 3610                                      de 3 a 4 anos
# 4171                                      de 1 a 2 anos
# 4200                                    Mais de 10 anos
# 4227                                     Menos de 1 ano
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?
# 562                                                 NaN
# 1528                                     Menos de 1 ano
# 1913                                      de 3 a 4 anos
# 1925                                     Menos de 1 ano
# 2554                                      de 1 a 2 anos
# 3090  Não tive experiência na área de TI/Engenharia ...
# 3357  Não tive experiência na área de TI/Engenharia ...
# 3493                                     Menos de 1 ano
# 3610  Não tive experiência na área de TI/Engenharia ...
# 4171                                     Menos de 1 ano
# 4200                                     de 7 a 10 anos
# 4227  Não tive experiência na área de TI/Engenharia ...
#
# [12 rows x 29 columns]

# %%
dados[dados['IDADE']>30]
# Out:
#                                     ID  IDADE FAIXA IDADE     GENERO  \
# 0     zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1     zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2     zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 4     zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
# 5     zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34   Feminino
# ...                                ...    ...         ...        ...
# 4257  043snvbsxn3fuyfe043j5comuyu8g6ba   46.0       45-49  Masculino
# 4260  03atvow8404tatt2iixjds03atvownkz   36.0       35-39  Masculino
# 4261  02xomoejng6c9152kde02xomww412qpg   33.0       30-34  Masculino
# 4262  02vlm03c29g3fcys8tj06102vlm0983h   31.0       30-34  Masculino
# 4264  028mfisr3mqazkn5n6swe028mt55nqzq   37.0       35-39  Masculino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0             Parda  Não  Não acredito que minha experiência profissiona...
# 1             Parda  Não  Sim, acredito que a minha a experiência profis...
# 2            Branca  Não                                                NaN
# 4            Branca  Não  Não acredito que minha experiência profissiona...
# 5             Parda  Não  Não acredito que minha experiência profissiona...
# ...             ...  ...                                                ...
# 4257        Amarela  Não  Não acredito que minha experiência profissiona...
# 4260          Parda  Não  Não acredito que minha experiência profissiona...
# 4261         Branca  Não                                                NaN
# 4262        Amarela  Não  Não acredito que minha experiência profissiona...
# 4264         Branca  Não                                                NaN
#
#       PREJUDICA?                         ASPECTOS_PREJUDICADOS  \
# 0          False                                           NaN
# 1           True  Aprovação em processos seletivos/entrevistas
# 2          False                                           NaN
# 4          False                                           NaN
# 5          False                                           NaN
# ...          ...                                           ...
# 4257       False                                           NaN
# 4260       False                                           NaN
# 4261       False                                           NaN
# 4262       False                                           NaN
# 4264       False                                           NaN
#
#       VIVE_NO_BRASIL  ...                           SETOR  \
# 0               True  ...                   Setor Público
# 1               True  ...                     Outra Opção
# 2               True  ...              Finanças ou Bancos
# 4               True  ...                   Setor Público
# 5               True  ...                        Educação
# ...              ...  ...                             ...
# 4257            True  ...              Finanças ou Bancos
# 4260            True  ...                             NaN
# 4261            True  ...                             NaN
# 4262            True  ...  Tecnologia/Fábrica de Software
# 4264            True  ...  Tecnologia/Fábrica de Software
#
#      NUMERO DE FUNCIONARIOS GESTOR?        CARGO COMO GESTOR  \
# 0            Acima de 3.000   False                      NaN
# 1            Acima de 3.000    True   Supervisor/Coordenador
# 2            Acima de 3.000   False                      NaN
# 4              de 101 a 500   False                      NaN
# 5            Acima de 3.000   False                      NaN
# ...                     ...     ...                      ...
# 4257         Acima de 3.000    True             Gerente/Head
# 4260                    NaN     NaN                      NaN
# 4261                    NaN     NaN                      NaN
# 4262         de 501 a 1.000    True  Team Leader/Tech Leader
# 4264            de 51 a 100    True             Gerente/Head
#
#                                             CARGO ATUAL   NIVEL  \
# 0                   DBA/Administrador de Banco de Dados  Júnior
# 1                                                   NaN     NaN
# 2     Desenvolvedor/ Engenheiro de Software/ Analist...   Pleno
# 4     Desenvolvedor/ Engenheiro de Software/ Analist...   Pleno
# 5                                             Professor   Pleno
# ...                                                 ...     ...
# 4257                                                NaN     NaN
# 4260                                                NaN     NaN
# 4261                                                NaN     NaN
# 4262                                                NaN     NaN
# 4264                                                NaN     NaN
#
#           NOVO NÍVEL                    FAIXA SALARIAL  \
# 0             Júnior   de R$ 8.001/mês a R$ 12.000/mês
# 1     Pessoa Gestora    de R$ 4.001/mês a R$ 6.000/mês
# 2              Pleno  de R$ 12.001/mês a R$ 16.000/mês
# 4              Pleno    de R$ 6.001/mês a R$ 8.000/mês
# 5              Pleno    de R$ 2.001/mês a R$ 3.000/mês
# ...              ...                               ...
# 4257  Pessoa Gestora            Acima de R$ 40.001/mês
# 4260             NaN                               NaN
# 4261             NaN                               NaN
# 4262  Pessoa Gestora  de R$ 16.001/mês a R$ 20.000/mês
# 4264  Pessoa Gestora  de R$ 20.001/mês a R$ 25.000/mês
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 0                                         de 1 a 2 anos
# 1                                         de 3 a 4 anos
# 2                                         de 3 a 4 anos
# 4                Não tenho experiência na área de dados
# 5                Não tenho experiência na área de dados
# ...                                                 ...
# 4257                                    Mais de 10 anos
# 4260                                                NaN
# 4261                                                NaN
# 4262                                      de 3 a 4 anos
# 4264                                      de 3 a 4 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?
# 0                                        de 7 a 10 anos
# 1                                        Menos de 1 ano
# 2                                       Mais de 10 anos
# 4                                       Mais de 10 anos
# 5     Não tive experiência na área de TI/Engenharia ...
# ...                                                 ...
# 4257  Não tive experiência na área de TI/Engenharia ...
# 4260                                                NaN
# 4261                                                NaN
# 4262                                      de 3 a 4 anos
# 4264                                    Mais de 10 anos
#
# [1956 rows x 29 columns]

# %%
dados[(dados['IDADE']>30) & (dados['GENERO']=='Feminino')]
# Out:
#                                     ID  IDADE FAIXA IDADE    GENERO  \
# 4     zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49  Feminino
# 5     zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34  Feminino
# 7     zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34  Feminino
# 14    zwez49k0jhdvfkfst4zwef137uuf4ivy   35.0       35-39  Feminino
# 23    zuqfcwtl9unfc5ezuqfcwm8coytsp5ap   46.0       45-49  Feminino
# ...                                ...    ...         ...       ...
# 4214  0gprow0ownrbfneftxf0gprow4kyrqdy   41.0       40-44  Feminino
# 4221  0fgi5bnb0u9b0fgc0jmqlbnvtu12b76d   34.0       30-34  Feminino
# 4240  0a5xgxb1ljmuqn0un8a10a5xg4eufs2l   37.0       35-39  Feminino
# 4247  07qzabp4ujpe4oz81udmb07qzabp4h0t   34.0       30-34  Feminino
# 4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34  Feminino
#
#      COR/RACA/ETNIA                   PCD  \
# 4            Branca                   Não
# 5             Parda                   Não
# 7            Branca                   Não
# 14            Parda                   Não
# 23           Branca                   Não
# ...             ...                   ...
# 4214         Branca  Prefiro não informar
# 4221          Outra                   Não
# 4240         Branca                   Não
# 4247         Branca                   Não
# 4251          Preta                   Não
#
#                    EXPERIENCIA_PROFISSIONAL_PREJUDICADA  PREJUDICA?  \
# 4     Não acredito que minha experiência profissiona...       False
# 5     Não acredito que minha experiência profissiona...       False
# 7     Não acredito que minha experiência profissiona...       False
# 14    Sim, acredito que a minha a experiência profis...       False
# 23    Não acredito que minha experiência profissiona...       False
# ...                                                 ...         ...
# 4214  Sim, acredito que a minha a experiência profis...        True
# 4221  Não acredito que minha experiência profissiona...       False
# 4240  Sim, acredito que a minha a experiência profis...        True
# 4247  Não acredito que minha experiência profissiona...       False
# 4251  Não acredito que minha experiência profissiona...       False
#
#                                   ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  ...  \
# 4                                                   NaN            True  ...
# 5                                                   NaN            True  ...
# 7                                                   NaN            True  ...
# 14    Atenção dada pelas pessoas diante das minhas o...            True  ...
# 23                                                  NaN            True  ...
# ...                                                 ...             ...  ...
# 4214  Oportunidades de progressão de carreira, Veloc...            True  ...
# 4221                                                NaN            True  ...
# 4240  Quantidade de oportunidades de emprego/vagas r...            True  ...
# 4247                                                NaN            True  ...
# 4251                                                NaN            True  ...
#
#                                SETOR NUMERO DE FUNCIONARIOS GESTOR?  \
# 4                      Setor Público           de 101 a 500   False
# 5                           Educação         Acima de 3.000   False
# 7     Tecnologia/Fábrica de Software              de 6 a 10   False
# 14                            Varejo         Acima de 3.000   False
# 23    Tecnologia/Fábrica de Software         de 501 a 1.000   False
# ...                              ...                    ...     ...
# 4214          Seguros ou Previdência         Acima de 3.000    True
# 4221             Área de Consultoria            de 51 a 100   False
# 4240              Finanças ou Bancos            de 51 a 100   False
# 4247                Setor de Energia             de 11 a 50   False
# 4251              Finanças ou Bancos       de 1.001 a 3.000   False
#
#            CARGO COMO GESTOR  \
# 4                        NaN
# 5                        NaN
# 7                        NaN
# 14                       NaN
# 23                       NaN
# ...                      ...
# 4214  Supervisor/Coordenador
# 4221                     NaN
# 4240                     NaN
# 4247                     NaN
# 4251                     NaN
#
#                                             CARGO ATUAL   NIVEL  \
# 4     Desenvolvedor/ Engenheiro de Software/ Analist...   Pleno
# 5                                             Professor   Pleno
# 7     Desenvolvedor/ Engenheiro de Software/ Analist...  Júnior
# 14                Analista de Negócios/Business Analyst   Pleno
# 23    Engenheiro de Dados/Arquiteto de Dados/Data En...  Sênior
# ...                                                 ...     ...
# 4214                                                NaN     NaN
# 4221                                        Outra Opção  Júnior
# 4240                          Analista de BI/BI Analyst  Júnior
# 4247                  Cientista de Dados/Data Scientist  Júnior
# 4251  Engenheiro de Dados/Arquiteto de Dados/Data En...   Pleno
#
#           NOVO NÍVEL                    FAIXA SALARIAL  \
# 4              Pleno    de R$ 6.001/mês a R$ 8.000/mês
# 5              Pleno    de R$ 2.001/mês a R$ 3.000/mês
# 7             Júnior    de R$ 2.001/mês a R$ 3.000/mês
# 14             Pleno    de R$ 6.001/mês a R$ 8.000/mês
# 23            Sênior  de R$ 12.001/mês a R$ 16.000/mês
# ...              ...                               ...
# 4214  Pessoa Gestora   de R$ 8.001/mês a R$ 12.000/mês
# 4221          Júnior    de R$ 4.001/mês a R$ 6.000/mês
# 4240          Júnior    de R$ 1.001/mês a R$ 2.000/mês
# 4247          Júnior    de R$ 4.001/mês a R$ 6.000/mês
# 4251           Pleno    de R$ 4.001/mês a R$ 6.000/mês
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 4                Não tenho experiência na área de dados
# 5                Não tenho experiência na área de dados
# 7                                        Menos de 1 ano
# 14                                        de 1 a 2 anos
# 23                                      Mais de 10 anos
# ...                                                 ...
# 4214                                      de 4 a 6 anos
# 4221                                     Menos de 1 ano
# 4240                                      de 1 a 2 anos
# 4247                                    Mais de 10 anos
# 4251                                     Menos de 1 ano
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?
# 4                                       Mais de 10 anos
# 5     Não tive experiência na área de TI/Engenharia ...
# 7                                        Menos de 1 ano
# 14    Não tive experiência na área de TI/Engenharia ...
# 23                                        de 5 a 6 anos
# ...                                                 ...
# 4214  Não tive experiência na área de TI/Engenharia ...
# 4221                                     Menos de 1 ano
# 4240                                     Menos de 1 ano
# 4247  Não tive experiência na área de TI/Engenharia ...
# 4251                                     Menos de 1 ano
#
# [503 rows x 29 columns]

# %%
dados[(dados['COR/RACA/ETNIA']=='Amarela') & (dados['IDADE']<40)]
# Out:
#                                     ID  IDADE FAIXA IDADE     GENERO  \
# 13    zwh83jpy6x40b95xigsr2zwh83jpflu3   24.0       22-24  Masculino
# 85    zfeuk2m9jozahicujlla8zfeuk2g7apj   29.0       25-29   Feminino
# 159   ytrnz3zyvn791t3dum1ytrnz3zp22tmk   37.0       35-39   Feminino
# 170   yri3z491ejizlpj9ylu2k3jyri3z4915   34.0       30-34  Masculino
# 195   yjbpxmkqz5yidh5oszyjbpxmkgcb1zd9   32.0       30-34  Masculino
# ...                                ...    ...         ...        ...
# 3947  2tnsh0gxdu3aq4z2d2tnsh0hk15brx7q   31.0       30-34   Feminino
# 4058  1t3ndwx8j50k0bz1t3ndwxdpwyg17c2k   27.0       25-29   Feminino
# 4176  0qpa64gqpieg60xpygnajt70qpa64g1a   27.0       25-29   Feminino
# 4207  0ibb8fj9qrwpswfqiil0ibb89e3e4hz3   30.0       30-34   Feminino
# 4262  02vlm03c29g3fcys8tj06102vlm0983h   31.0       30-34  Masculino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 13          Amarela  Não  Não acredito que minha experiência profissiona...
# 85          Amarela  Não  Não acredito que minha experiência profissiona...
# 159         Amarela  Não  Sim, acredito que a minha a experiência profis...
# 170         Amarela  Não  Não acredito que minha experiência profissiona...
# 195         Amarela  Não  Não acredito que minha experiência profissiona...
# ...             ...  ...                                                ...
# 3947        Amarela  Não  Sim, acredito que a minha a experiência profis...
# 4058        Amarela  Não  Sim, acredito que a minha a experiência profis...
# 4176        Amarela  Não  Não acredito que minha experiência profissiona...
# 4207        Amarela  Não  Sim, acredito que a minha a experiência profis...
# 4262        Amarela  Não  Não acredito que minha experiência profissiona...
#
#       PREJUDICA?                              ASPECTOS_PREJUDICADOS  \
# 13         False                                                NaN
# 85         False                                                NaN
# 159        False  Oportunidades de progressão de carreira, Aprov...
# 170        False                                                NaN
# 195        False                                                NaN
# ...          ...                                                ...
# 3947       False  Quantidade de oportunidades de emprego/vagas r...
# 4058        True  Nível de cobrança no trabalho / Stress no trab...
# 4176       False                                                NaN
# 4207        True  Oportunidades de progressão de carreira, Veloc...
# 4262       False                                                NaN
#
#       VIVE_NO_BRASIL  ...                           SETOR  \
# 13              True  ...              Finanças ou Bancos
# 85              True  ...                             NaN
# 159             True  ...  Tecnologia/Fábrica de Software
# 170             True  ...                          Varejo
# 195             True  ...                             NaN
# ...              ...  ...                             ...
# 3947           False  ...  Tecnologia/Fábrica de Software
# 4058            True  ...  Tecnologia/Fábrica de Software
# 4176            True  ...                             NaN
# 4207            True  ...             Área de Consultoria
# 4262            True  ...  Tecnologia/Fábrica de Software
#
#      NUMERO DE FUNCIONARIOS GESTOR?        CARGO COMO GESTOR  \
# 13           Acima de 3.000   False                      NaN
# 85                      NaN     NaN                      NaN
# 159            de 101 a 500   False                      NaN
# 170          Acima de 3.000    True             Gerente/Head
# 195                     NaN     NaN                      NaN
# ...                     ...     ...                      ...
# 3947         Acima de 3.000    True   Supervisor/Coordenador
# 4058         Acima de 3.000   False                      NaN
# 4176                    NaN     NaN                      NaN
# 4207         de 501 a 1.000   False                      NaN
# 4262         de 501 a 1.000    True  Team Leader/Tech Leader
#
#                                             CARGO ATUAL   NIVEL  \
# 13                Analista de Negócios/Business Analyst  Júnior
# 85                                                  NaN     NaN
# 159   Engenheiro de Dados/Arquiteto de Dados/Data En...   Pleno
# 170                                                 NaN     NaN
# 195                                                 NaN     NaN
# ...                                                 ...     ...
# 3947                                                NaN     NaN
# 4058                  Cientista de Dados/Data Scientist  Sênior
# 4176                                                NaN     NaN
# 4207                  Cientista de Dados/Data Scientist  Sênior
# 4262                                                NaN     NaN
#
#           NOVO NÍVEL                    FAIXA SALARIAL  \
# 13            Júnior    de R$ 4.001/mês a R$ 6.000/mês
# 85               NaN                               NaN
# 159            Pleno   de R$ 8.001/mês a R$ 12.000/mês
# 170   Pessoa Gestora  de R$ 16.001/mês a R$ 20.000/mês
# 195              NaN                               NaN
# ...              ...                               ...
# 3947  Pessoa Gestora  de R$ 25.001/mês a R$ 30.000/mês
# 4058          Sênior  de R$ 12.001/mês a R$ 16.000/mês
# 4176             NaN                               NaN
# 4207          Sênior  de R$ 16.001/mês a R$ 20.000/mês
# 4262  Pessoa Gestora  de R$ 16.001/mês a R$ 20.000/mês
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 13                                        de 1 a 2 anos
# 85                                                  NaN
# 159                                       de 1 a 2 anos
# 170                                       de 3 a 4 anos
# 195                                                 NaN
# ...                                                 ...
# 3947                                      de 1 a 2 anos
# 4058                                      de 4 a 6 anos
# 4176                                                NaN
# 4207                                      de 4 a 6 anos
# 4262                                      de 3 a 4 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?
# 13                                       Menos de 1 ano
# 85                                                  NaN
# 159                                      de 7 a 10 anos
# 170   Não tive experiência na área de TI/Engenharia ...
# 195                                                 NaN
# ...                                                 ...
# 3947  Não tive experiência na área de TI/Engenharia ...
# 4058  Não tive experiência na área de TI/Engenharia ...
# 4176                                                NaN
# 4207                                      de 5 a 6 anos
# 4262                                      de 3 a 4 anos
#
# [101 rows x 29 columns]

# %%
dados.groupby('GENERO')['ID'].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# Name: ID, dtype: int64

# %%
dados['GENERO'].value_counts(dropna=False)
# Out:
# GENERO
# Masculino               3194
# Feminino                1056
# Prefiro não informar      12
# NaN                        9
# Name: count, dtype: int64

# %%
dados[dados['IDADE']>30]['NIVEL'].value_counts()
# Out:
# NIVEL
# Sênior    525
# Pleno     408
# Júnior    274
# Name: count, dtype: int64

# %%
dados[(dados['IDADE']>30) & (dados['GENERO']=='Feminino')]['NIVEL'].value_counts()
# Out:
# NIVEL
# Pleno     117
# Sênior    114
# Júnior     96
# Name: count, dtype: int64

# %%
pd.pivot_table(dados, values=['ID'], index=['GENERO'], columns=['GESTOR?'], aggfunc='count')
# Out:
#                         ID
# GESTOR?              False True
# GENERO
# Feminino               754   132
# Masculino             2212   578
# Prefiro não informar     9     2

# %% [markdown]
# #Estatística Básica

# %%
import numpy as np

# %%
lista_idades = [26, 30, 32, 22, 26, 35, 40, 20, 43, 31, 23]

# %%
np.sum(lista_idades)
# Out:
# np.int64(328)

# %%
len(lista_idades)
# Out:
# 11

# %%
np.sum(lista_idades)/len(lista_idades) #media de idades
# Out:
# np.float64(29.818181818181817)

# %%
media = np.mean(lista_idades)
print("Media aritmética:", media)
# Out:
# Media aritmética: 29.818181818181817

# %%
lista_idades.sort() #organizar as idades em ordem crescente
lista_idades
# Out:
# [20, 22, 23, 26, 26, 30, 31, 32, 35, 40, 43]

# %%
lista_idades = [26, 30, 32, 22, 26, 35, 40, 20, 43, 31, 23]

# %%
#ordenando em ordem crescente
lista_idades.sort()
lista_idades
# Out:
# [20, 22, 23, 26, 26, 30, 31, 32, 35, 40, 43]

# %%
mediana = np.median(lista_idades)
mediana
# Out:
# np.float64(30.0)

# %% [markdown]
# #Voltando para a tabela

# %%
dados['IDADE'].mean() #media da idade
# Out:
# np.float64(31.169168453657374)

# %%
dados['IDADE'].median() #mediana da idade
# Out:
# 30.0

# %%
dados['IDADE'].mode() #moda dos dados
# Out:
# 0    27.0
# Name: IDADE, dtype: float64

# %%
dados['IDADE'].std() #desvio padrao da idade
# Out:
# 6.902802832143141

# %% [markdown]
# O valor 7 é alto, pois não há tantas linhas nessa tabela. O desvio padrão alto significa que a faixa de idades é muito grande.

# %%
dados['IDADE'].min()
# Out:
# 18.0

# %%
#shift enter ja coloca a celula nova de codigo embaixo.
dados['IDADE'].max()
# Out:
# 54.0

# %%
dados[dados['GENERO']=='Feminino']['IDADE'].mean()
# Out:
# np.float64(31.318051575931232)

# %%
dados
# Out:
#                                     ID  IDADE FAIXA IDADE     GENERO  \
# 0     zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1     zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2     zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3     zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4     zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
# ...                                ...    ...         ...        ...
# 4266  01jnrn9f6va0menfhk2ztm01jnrn96bp   26.0       25-29  Masculino
# 4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34   Feminino
# 4268  00zw9ks9d40z4u00zz3d20iix65qpli3   29.0       25-29  Masculino
# 4269  00xu7yujd7s57emj00xu7y0c3njix3de    NaN       17-21  Masculino
# 4270  00lb35llmdsidpa00lb35qcdysnzvhv7   24.0       22-24  Masculino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0             Parda  Não  Não acredito que minha experiência profissiona...
# 1             Parda  Não  Sim, acredito que a minha a experiência profis...
# 2            Branca  Não                                                NaN
# 3            Branca  Não                                                NaN
# 4            Branca  Não  Não acredito que minha experiência profissiona...
# ...             ...  ...                                                ...
# 4266         Branca  Não                                                NaN
# 4267         Branca  Não  Não acredito que minha experiência profissiona...
# 4268         Branca  Não                                                NaN
# 4269         Branca  Não                                                NaN
# 4270         Branca  Não                                                NaN
#
#       PREJUDICA?                         ASPECTOS_PREJUDICADOS  \
# 0          False                                           NaN
# 1           True  Aprovação em processos seletivos/entrevistas
# 2          False                                           NaN
# 3          False                                           NaN
# 4          False                                           NaN
# ...          ...                                           ...
# 4266       False                                           NaN
# 4267       False                                           NaN
# 4268       False                                           NaN
# 4269       False                                           NaN
# 4270       False                                           NaN
#
#       VIVE_NO_BRASIL  ...                                SETOR  \
# 0               True  ...                        Setor Público
# 1               True  ...                          Outra Opção
# 2               True  ...                   Finanças ou Bancos
# 3               True  ...                     Setor Automotivo
# 4               True  ...                        Setor Público
# ...              ...  ...                                  ...
# 4266            True  ...       Tecnologia/Fábrica de Software
# 4267            True  ...                  Área de Consultoria
# 4268            True  ...  Setor Imobiliário/ Construção Civil
# 4269            True  ...                            Indústria
# 4270            True  ...                         Agronegócios
#
#      NUMERO DE FUNCIONARIOS GESTOR?       CARGO COMO GESTOR  \
# 0            Acima de 3.000   False                     NaN
# 1            Acima de 3.000    True  Supervisor/Coordenador
# 2            Acima de 3.000   False                     NaN
# 3            Acima de 3.000   False                     NaN
# 4              de 101 a 500   False                     NaN
# ...                     ...     ...                     ...
# 4266         Acima de 3.000   False                     NaN
# 4267            de 51 a 100   False                     NaN
# 4268           de 101 a 500    True            Gerente/Head
# 4269       de 1.001 a 3.000   False                     NaN
# 4270         de 501 a 1.000   False                     NaN
#
#                                             CARGO ATUAL   NIVEL  \
# 0                   DBA/Administrador de Banco de Dados  Júnior
# 1                                                   NaN     NaN
# 2     Desenvolvedor/ Engenheiro de Software/ Analist...   Pleno
# 3                     Cientista de Dados/Data Scientist  Sênior
# 4     Desenvolvedor/ Engenheiro de Software/ Analist...   Pleno
# ...                                                 ...     ...
# 4266                     Analista de Dados/Data Analyst   Pleno
# 4267  Engenheiro de Dados/Arquiteto de Dados/Data En...   Pleno
# 4268                                                NaN     NaN
# 4269                                        Outra Opção  Júnior
# 4270                     Analista de Dados/Data Analyst  Júnior
#
#           NOVO NÍVEL                    FAIXA SALARIAL  \
# 0             Júnior   de R$ 8.001/mês a R$ 12.000/mês
# 1     Pessoa Gestora    de R$ 4.001/mês a R$ 6.000/mês
# 2              Pleno  de R$ 12.001/mês a R$ 16.000/mês
# 3             Sênior  de R$ 12.001/mês a R$ 16.000/mês
# 4              Pleno    de R$ 6.001/mês a R$ 8.000/mês
# ...              ...                               ...
# 4266           Pleno    de R$ 4.001/mês a R$ 6.000/mês
# 4267           Pleno    de R$ 3.001/mês a R$ 4.000/mês
# 4268  Pessoa Gestora  de R$ 16.001/mês a R$ 20.000/mês
# 4269          Júnior             Menos de R$ 1.000/mês
# 4270          Júnior    de R$ 3.001/mês a R$ 4.000/mês
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 0                                         de 1 a 2 anos
# 1                                         de 3 a 4 anos
# 2                                         de 3 a 4 anos
# 3                                         de 4 a 6 anos
# 4                Não tenho experiência na área de dados
# ...                                                 ...
# 4266                                      de 3 a 4 anos
# 4267                                      de 1 a 2 anos
# 4268                                      de 4 a 6 anos
# 4269                                     Menos de 1 ano
# 4270                                      de 1 a 2 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?
# 0                                        de 7 a 10 anos
# 1                                        Menos de 1 ano
# 2                                       Mais de 10 anos
# 3     Não tive experiência na área de TI/Engenharia ...
# 4                                       Mais de 10 anos
# ...                                                 ...
# 4266                                     de 7 a 10 anos
# 4267  Não tive experiência na área de TI/Engenharia ...
# 4268  Não tive experiência na área de TI/Engenharia ...
# 4269  Não tive experiência na área de TI/Engenharia ...
# 4270  Não tive experiência na área de TI/Engenharia ...
#
# [4271 rows x 29 columns]

# %% [markdown]
# #Valores Faltantes

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4271 entries, 0 to 4270
# Data columns (total 29 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   ID                                                                                                                         4271 non-null   object
#  1   IDADE                                                                                                                      4197 non-null   float64
#  2   FAIXA IDADE                                                                                                                4271 non-null   object
#  3   GENERO                                                                                                                     4262 non-null   object
#  4   COR/RACA/ETNIA                                                                                                             4271 non-null   object
#  5   PCD                                                                                                                        4271 non-null   object
#  6   EXPERIENCIA_PROFISSIONAL_PREJUDICADA                                                                                       2190 non-null   object
#  7   PREJUDICA?                                                                                                                 4271 non-null   bool
#  8   ASPECTOS_PREJUDICADOS                                                                                                      837 non-null    object
#  9   VIVE_NO_BRASIL                                                                                                             4271 non-null   bool
#  10  ESTADO ONDE MORA                                                                                                           4156 non-null   object
#  11  UF ONDE MORA                                                                                                               4156 non-null   object
#  12  REGIAO ONDE MORA                                                                                                           4171 non-null   object
#  13  MUDOU DE ESTADO?                                                                                                           4171 non-null   object
#  14  REGIAO DE ORIGEM                                                                                                           772 non-null    object
#  15  NIVEL DE ENSINO                                                                                                            4271 non-null   object
#  16  ÁREA DE FORMAÇÃO                                                                                                           4149 non-null   object
#  17  COMPUTAÇÃO?                                                                                                                4271 non-null   bool
#  18  QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?                                                                                       4271 non-null   object
#  19  SETOR                                                                                                                      3694 non-null   object
#  20  NUMERO DE FUNCIONARIOS                                                                                                     3694 non-null   object
#  21  GESTOR?                                                                                                                    3694 non-null   object
#  22  CARGO COMO GESTOR                                                                                                          713 non-null    object
#  23  CARGO ATUAL                                                                                                                2981 non-null   object
#  24  NIVEL                                                                                                                      2981 non-null   object
#  25  NOVO NÍVEL                                                                                                                 3694 non-null   object
#  26  FAIXA SALARIAL                                                                                                             3694 non-null   object
#  27  QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?                                                                     3694 non-null   object
#  28  QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  3694 non-null   object
# dtypes: bool(3), float64(1), object(25)
# memory usage: 880.2+ KB

# %% [markdown]
# ##Trabalhando coluna de gênero

# %%
dados.groupby('GENERO', dropna=False)['ID'].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# NaN                        9
# Name: ID, dtype: int64

# %%
dados['GENERO'].fillna("Prefiro não informar")
# Out:
# 0       Masculino
# 1       Masculino
# 2       Masculino
# 3       Masculino
# 4        Feminino
#           ...
# 4266    Masculino
# 4267     Feminino
# 4268    Masculino
# 4269    Masculino
# 4270    Masculino
# Name: GENERO, Length: 4271, dtype: object

# %%
dados['GENERO'] = dados['GENERO'].fillna("Prefiro não informar")

# %%
dados.groupby('GENERO', dropna=False)['ID'].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      21
# Name: ID, dtype: int64

# %% [markdown]
# ### Trabalhando coluna de Idade

# %%
dados['IDADE'].isnull().value_counts()
# Out:
# IDADE
# False    4197
# True       74
# Name: count, dtype: int64

# %% [markdown]
# Vou filtrar as pessoas que deixaram a idade nula pela faixa de idade.

# %%
dados[dados['IDADE'].isnull()]['FAIXA IDADE'].value_counts()
# Out:
# FAIXA IDADE
# 55+      68
# 17-21     6
# Name: count, dtype: int64

# %%
# vamos pegar a média da faixa de idades

# %%
media_17_21 = dados[dados['FAIXA IDADE']=='17-21']['IDADE'].mean()

# %%
#FILTRA AS LINHAS DA FAIXA 17-21 QUE ESTÃO NULAS
dados.loc[(dados['FAIXA IDADE']=='17-21') & (dados['IDADE'].isnull()), 'IDADE']
# Out:
# 1925   NaN
# 2393   NaN
# 3367   NaN
# 4086   NaN
# 4177   NaN
# 4269   NaN
# Name: IDADE, dtype: float64

# %%
#AGORA ATRIBUINDO OS VALORES NOVOS
dados.loc[(dados['FAIXA IDADE']=='17-21') & (dados['IDADE'].isnull()), 'IDADE'] = media_17_21

# %%
dados[dados['IDADE'].isnull()]['FAIXA IDADE'].value_counts()
# Out:
# FAIXA IDADE
# 55+    68
# Name: count, dtype: int64

# %%
# a media nao deu certo, vamos ver o nivel pra ver se a pessoa nao quis marcar a idade ou se foi algum erro de formulario
dados[dados['FAIXA IDADE']=='55+']['IDADE']
# Out:
# 9      NaN
# 66     NaN
# 96     NaN
# 121    NaN
# 156    NaN
#         ..
# 4001   NaN
# 4043   NaN
# 4048   NaN
# 4061   NaN
# 4215   NaN
# Name: IDADE, Length: 68, dtype: float64

# %%
dados[dados['FAIXA IDADE']=='55+']['NIVEL']
# Out:
# 9        Pleno
# 66      Júnior
# 96       Pleno
# 121      Pleno
# 156     Júnior
#          ...
# 4001       NaN
# 4043       NaN
# 4048       NaN
# 4061       NaN
# 4215    Sênior
# Name: NIVEL, Length: 68, dtype: object

# %%
media_geral = dados['IDADE'].mean()

# %%
media_geral
# Out:
# np.float64(31.153517220250375)

# %%
dados.loc[(dados['FAIXA IDADE']=='55+') & (dados['IDADE'].isnull()), 'IDADE'] = media_geral

# %%
dados[dados['IDADE'].isnull()]['FAIXA IDADE'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# # Valores Discrepantes

# %%
lista_idades = [26, 30, 32, 22, 26, 35, 400, 20, 43, 31, 23]

# %%
np.mean(lista_idades)
# Out:
# np.float64(62.54545454545455)

# %%
desvio = np.std(lista_idades)
desvio
# Out:
# np.float64(106.89532997398872)

# %%
media + 3*desvio #limite superior
# Out:
# np.float64(350.50417174014797)

# %%
media - 3*desvio #limite inferior
# Out:
# np.float64(-290.86780810378434)

# %%
#quartis -> caso os limites estejam estranhos..
#existe um metodo de visualização chamado boxplot
import matplotlib.pyplot as plt

# %%
plt.boxplot(lista_idades)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e9095820810>,
#   <matplotlib.lines.Line2D at 0x7e9095823c50>],
#  'caps': [<matplotlib.lines.Line2D at 0x7e9095823790>,
#   <matplotlib.lines.Line2D at 0x7e9095814250>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7e90958af310>],
#  'medians': [<matplotlib.lines.Line2D at 0x7e9095816bd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7e9095814cd0>],
#  'means': []}

# %% [markdown]
# # Featuring Engineering

# %%
def preencher_nivel(gestor,nivel):
  if gestor == 1:
    return "Pessoa gestora"
  else:
    return nivel

# %%
dados['NOVO NIVEL'] = dados.apply(lambda x: preencher_nivel(x['GESTOR?'], x['NIVEL']), axis = 1)

# %%
dados['NOVO NIVEL'].value_counts()
# Out:
# NOVO NIVEL
# Pleno             1060
# Júnior            1023
# Sênior             898
# Pessoa gestora     713
# Name: count, dtype: int64

# %%
pd.get_dummies(dados, columns=['NIVEL']) #novas colunas
# Out:
#                                     ID      IDADE FAIXA IDADE     GENERO  \
# 0     zzqzz3l9ily8nuo2m7wyzzqzz3w48o96  39.000000       35-39  Masculino
# 1     zzls2oftfn9law393oezzls2ofhvfpzd  32.000000       30-34  Masculino
# 2     zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi  53.000000       50-54  Masculino
# 3     zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl  27.000000       25-29  Masculino
# 4     zzaf1m95yan929rb94wzzaf1mekhvhpg  46.000000       45-49   Feminino
# ...                                ...        ...         ...        ...
# 4266  01jnrn9f6va0menfhk2ztm01jnrn96bp  26.000000       25-29  Masculino
# 4267  01dyfxam4u4bi29fem01dyfxaq9akvqp  30.000000       30-34   Feminino
# 4268  00zw9ks9d40z4u00zz3d20iix65qpli3  29.000000       25-29  Masculino
# 4269  00xu7yujd7s57emj00xu7y0c3njix3de  20.205479       17-21  Masculino
# 4270  00lb35llmdsidpa00lb35qcdysnzvhv7  24.000000       22-24  Masculino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0             Parda  Não  Não acredito que minha experiência profissiona...
# 1             Parda  Não  Sim, acredito que a minha a experiência profis...
# 2            Branca  Não                                                NaN
# 3            Branca  Não                                                NaN
# 4            Branca  Não  Não acredito que minha experiência profissiona...
# ...             ...  ...                                                ...
# 4266         Branca  Não                                                NaN
# 4267         Branca  Não  Não acredito que minha experiência profissiona...
# 4268         Branca  Não                                                NaN
# 4269         Branca  Não                                                NaN
# 4270         Branca  Não                                                NaN
#
#       PREJUDICA?                         ASPECTOS_PREJUDICADOS  \
# 0          False                                           NaN
# 1           True  Aprovação em processos seletivos/entrevistas
# 2          False                                           NaN
# 3          False                                           NaN
# 4          False                                           NaN
# ...          ...                                           ...
# 4266       False                                           NaN
# 4267       False                                           NaN
# 4268       False                                           NaN
# 4269       False                                           NaN
# 4270       False                                           NaN
#
#       VIVE_NO_BRASIL  ...       CARGO COMO GESTOR  \
# 0               True  ...                     NaN
# 1               True  ...  Supervisor/Coordenador
# 2               True  ...                     NaN
# 3               True  ...                     NaN
# 4               True  ...                     NaN
# ...              ...  ...                     ...
# 4266            True  ...                     NaN
# 4267            True  ...                     NaN
# 4268            True  ...            Gerente/Head
# 4269            True  ...                     NaN
# 4270            True  ...                     NaN
#
#                                             CARGO ATUAL      NOVO NÍVEL  \
# 0                   DBA/Administrador de Banco de Dados          Júnior
# 1                                                   NaN  Pessoa Gestora
# 2     Desenvolvedor/ Engenheiro de Software/ Analist...           Pleno
# 3                     Cientista de Dados/Data Scientist          Sênior
# 4     Desenvolvedor/ Engenheiro de Software/ Analist...           Pleno
# ...                                                 ...             ...
# 4266                     Analista de Dados/Data Analyst           Pleno
# 4267  Engenheiro de Dados/Arquiteto de Dados/Data En...           Pleno
# 4268                                                NaN  Pessoa Gestora
# 4269                                        Outra Opção          Júnior
# 4270                     Analista de Dados/Data Analyst          Júnior
#
#                         FAIXA SALARIAL  \
# 0      de R$ 8.001/mês a R$ 12.000/mês
# 1       de R$ 4.001/mês a R$ 6.000/mês
# 2     de R$ 12.001/mês a R$ 16.000/mês
# 3     de R$ 12.001/mês a R$ 16.000/mês
# 4       de R$ 6.001/mês a R$ 8.000/mês
# ...                                ...
# 4266    de R$ 4.001/mês a R$ 6.000/mês
# 4267    de R$ 3.001/mês a R$ 4.000/mês
# 4268  de R$ 16.001/mês a R$ 20.000/mês
# 4269             Menos de R$ 1.000/mês
# 4270    de R$ 3.001/mês a R$ 4.000/mês
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 0                                         de 1 a 2 anos
# 1                                         de 3 a 4 anos
# 2                                         de 3 a 4 anos
# 3                                         de 4 a 6 anos
# 4                Não tenho experiência na área de dados
# ...                                                 ...
# 4266                                      de 3 a 4 anos
# 4267                                      de 1 a 2 anos
# 4268                                      de 4 a 6 anos
# 4269                                     Menos de 1 ano
# 4270                                      de 1 a 2 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  \
# 0                                        de 7 a 10 anos
# 1                                        Menos de 1 ano
# 2                                       Mais de 10 anos
# 3     Não tive experiência na área de TI/Engenharia ...
# 4                                       Mais de 10 anos
# ...                                                 ...
# 4266                                     de 7 a 10 anos
# 4267  Não tive experiência na área de TI/Engenharia ...
# 4268  Não tive experiência na área de TI/Engenharia ...
# 4269  Não tive experiência na área de TI/Engenharia ...
# 4270  Não tive experiência na área de TI/Engenharia ...
#
#           NOVO NIVEL  NIVEL_Júnior NIVEL_Pleno NIVEL_Sênior
# 0             Júnior          True       False        False
# 1     Pessoa gestora         False       False        False
# 2              Pleno         False        True        False
# 3             Sênior         False       False         True
# 4              Pleno         False        True        False
# ...              ...           ...         ...          ...
# 4266           Pleno         False        True        False
# 4267           Pleno         False        True        False
# 4268  Pessoa gestora         False       False        False
# 4269          Júnior          True       False        False
# 4270          Júnior          True       False        False
#
# [4271 rows x 32 columns]

# %%
dados = pd.get_dummies(dados, columns=['NIVEL']) #add colunas

# %%
def determinar_geracao(idade):
  if 39 < idade <= 58:
    return "Geração X"
  elif 29 < idade <= 39:
    return "Millenium"
  elif 13< idade <= 29:
    return "Geração Z"
  else:
    return "Outra Geração"

# %%
dados['GERAÇAO'] = dados['IDADE'].apply(determinar_geracao)

# %%
dados['GERAÇAO'].value_counts()
# Out:
# GERAÇAO
# Geração Z    1999
# Millenium    1761
# Geração X     511
# Name: count, dtype: int64

# %%
dados2 = pd.read_excel('/content/drive/MyDrive/Analise de Dados PrograMaria/Cópia de Planilha_Aula_parte2.xlsx')

# %%
dados.head()
# Out:
#                                  ID  IDADE FAIXA IDADE     GENERO  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
#
#   COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0          Parda  Não  Não acredito que minha experiência profissiona...
# 1          Parda  Não  Sim, acredito que a minha a experiência profis...
# 2         Branca  Não                                                NaN
# 3         Branca  Não                                                NaN
# 4         Branca  Não  Não acredito que minha experiência profissiona...
#
#    PREJUDICA?                         ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  \
# 0       False                                           NaN            True
# 1        True  Aprovação em processos seletivos/entrevistas            True
# 2       False                                           NaN            True
# 3       False                                           NaN            True
# 4       False                                           NaN            True
#
#    ...                                        CARGO ATUAL      NOVO NÍVEL  \
# 0  ...                DBA/Administrador de Banco de Dados          Júnior
# 1  ...                                                NaN  Pessoa Gestora
# 2  ...  Desenvolvedor/ Engenheiro de Software/ Analist...           Pleno
# 3  ...                  Cientista de Dados/Data Scientist          Sênior
# 4  ...  Desenvolvedor/ Engenheiro de Software/ Analist...           Pleno
#
#                      FAIXA SALARIAL  \
# 0   de R$ 8.001/mês a R$ 12.000/mês
# 1    de R$ 4.001/mês a R$ 6.000/mês
# 2  de R$ 12.001/mês a R$ 16.000/mês
# 3  de R$ 12.001/mês a R$ 16.000/mês
# 4    de R$ 6.001/mês a R$ 8.000/mês
#
#   QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 0                                      de 1 a 2 anos
# 1                                      de 3 a 4 anos
# 2                                      de 3 a 4 anos
# 3                                      de 4 a 6 anos
# 4             Não tenho experiência na área de dados
#
#   QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  \
# 0                                     de 7 a 10 anos
# 1                                     Menos de 1 ano
# 2                                    Mais de 10 anos
# 3  Não tive experiência na área de TI/Engenharia ...
# 4                                    Mais de 10 anos
#
#        NOVO NIVEL NIVEL_Júnior  NIVEL_Pleno NIVEL_Sênior    GERAÇAO
# 0          Júnior         True        False        False  Millenium
# 1  Pessoa gestora        False        False        False  Millenium
# 2           Pleno        False         True        False  Geração X
# 3          Sênior        False        False         True  Geração Z
# 4           Pleno        False         True        False  Geração X
#
# [5 rows x 33 columns]

# %%
dados2.head()
# Out:
#                                  ID  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96
# 1  zzls2oftfn9law393oezzls2ofhvfpzd
# 2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi
# 3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl
# 4  zzaf1m95yan929rb94wzzaf1mekhvhpg
#
#   Quanto tempo de experiência na área de dados você tem?  \
# 0                                      de 1 a 2 anos
# 1                                      de 3 a 4 anos
# 2                                      de 3 a 4 anos
# 3                                      de 4 a 6 anos
# 4             Não tenho experiência na área de dados
#
#   Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?  \
# 0                                     de 7 a 10 anos
# 1                                     Menos de 1 ano
# 2                                    Mais de 10 anos
# 3  Não tive experiência na área de TI/Engenharia ...
# 4                                    Mais de 10 anos
#
#   Você está satisfeito na sua empresa atual?  \
# 0                                       True
# 1                                      False
# 2                                      False
# 3                                       True
# 4                                      False
#
#   Qual o principal motivo da sua insatisfação com a empresa atual?  \
# 0                                                NaN
# 1  Falta de oportunidade de crescimento no empreg...
# 2  Falta de oportunidade de crescimento no empreg...
# 3                                                NaN
# 4  Falta de oportunidade de crescimento no empreg...
#
#   Você participou de entrevistas de emprego nos últimos 6 meses?  \
# 0  Não participei de entrevistas de emprego/proce...
# 1          Sim, fiz entrevistas mas não fui aprovado
# 2  Não participei de entrevistas de emprego/proce...
# 3               Sim, fui aprovado e mudei de emprego
# 4  Não participei de entrevistas de emprego/proce...
#
#   Você pretende mudar de emprego nos próximos 6 meses?  \
# 0  Não estou buscando e não pretendo mudar de emp...
# 1  Estou em busca de oportunidades dentro ou fora...
# 2  Não estou buscando, mas me considero aberto a ...
# 3  Não estou buscando, mas me considero aberto a ...
# 4  Não estou buscando, mas me considero aberto a ...
#
#   Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?  \
# 0                                         Benefícios
# 1  Remuneração/Salário, Plano de carreira e oport...
# 2  Remuneração/Salário, Flexibilidade de trabalho...
# 3  Remuneração/Salário, Flexibilidade de trabalho...
# 4  Remuneração/Salário, Oportunidade de aprendiza...
#
#             Atualmente qual a sua forma de trabalho?  \
# 0                             Modelo 100% presencial
# 1                             Modelo 100% presencial
# 2  Modelo híbrido com dias fixos de trabalho pres...
# 3  Modelo híbrido flexível (o funcionário tem lib...
# 4                             Modelo 100% presencial
#
#            Qual a forma de trabalho ideal para você?  \
# 0  Modelo híbrido com dias fixos de trabalho pres...
# 1  Modelo híbrido flexível (o funcionário tem lib...
# 2  Modelo híbrido flexível (o funcionário tem lib...
# 3  Modelo híbrido flexível (o funcionário tem lib...
# 4                             Modelo 100% presencial
#
#   Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?  \
# 0   Vou aceitar e retornar ao modelo 100% presencial
# 1   Vou aceitar e retornar ao modelo 100% presencial
# 2  Vou procurar outra oportunidade no modelo híbr...
# 3  Vou procurar outra oportunidade no modelo híbr...
# 4   Vou aceitar e retornar ao modelo 100% presencial
#
#                Sua empresa passu por Layoff em 2022?  \
# 0  Não ocorreram layoffs/demissões em massa na em...
# 1  Não ocorreram layoffs/demissões em massa na em...
# 2  Não ocorreram layoffs/demissões em massa na em...
# 3  Não ocorreram layoffs/demissões em massa na em...
# 4  Não ocorreram layoffs/demissões em massa na em...
#
#                                              Atuacao  \
# 0                                Engenharia de Dados
# 1                                             Gestor
# 2   desenvolve modelos preditivos e algoritmos de...
# 3   desenvolve modelos preditivos e algoritmos de...
# 4                                      Outra atuação
#
#   Quais das linguagens listadas abaixo você utiliza no trabalho?
# 0                                                SQL
# 1                                                NaN
# 2                                                  1
# 3                                                  0
# 4                                                SQL

# %%
dados = dados.merge(dados2, on='ID', how='left')

# %%
dados['Você pretende mudar de emprego nos próximos 6 meses?'].value_counts()
# Out:
# Você pretende mudar de emprego nos próximos 6 meses?
# Não estou buscando, mas me considero aberto a outras oportunidades         1354
# Estou em busca de oportunidades dentro ou fora do Brasil                   1011
# Não estou buscando e não pretendo mudar de emprego nos próximos 6 meses     978
# Estou em busca de oportunidades, mas apenas fora do Brasil                  353
# Name: count, dtype: int64

# %%
dados.columns
# Out:
# Index(['ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD',
#        'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'PREJUDICA?',
#        'ASPECTOS_PREJUDICADOS', 'VIVE_NO_BRASIL', 'ESTADO ONDE MORA',
#        'UF ONDE MORA', 'REGIAO ONDE MORA', 'MUDOU DE ESTADO?',
#        'REGIAO DE ORIGEM', 'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'COMPUTAÇÃO?', 'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NOVO NÍVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'NOVO NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior', 'GERAÇAO',
#        'Quanto tempo de experiência na área de dados você tem?',
#        'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
#        'Você está satisfeito na sua empresa atual?',
#        'Qual o principal motivo da sua insatisfação com a empresa atual?',
#        'Você participou de entrevistas de emprego nos últimos 6 meses?',
#        'Você pretende mudar de emprego nos próximos 6 meses?',
#        'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?',
#        'Atualmente qual a sua forma de trabalho?',
#        'Qual a forma de trabalho ideal para você?',
#        'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?',
#        'Sua empresa passu por Layoff em 2022?', 'Atuacao',
#        'Quais das linguagens listadas abaixo você utiliza no trabalho?'],
#       dtype='object')

# %%
dados['EM_BUSCA'] = dados['Você pretende mudar de emprego nos próximos 6 meses?'].str.contains('em busca', case=False)

# %%
dados['EM_BUSCA'].value_counts()
# Out:
# EM_BUSCA
# False    2332
# True     1364
# Name: count, dtype: int64

# %%
dados['Aberto a oportunidades'] = dados['Você pretende mudar de emprego nos próximos 6 meses?'].str.contains('aberto', case=False)

# %%
dados['Aberto a oportunidades'].value_counts()
# Out:
# Aberto a oportunidades
# False    2342
# True     1354
# Name: count, dtype: int64

# %%
dados.columns
# Out:
# Index(['ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD',
#        'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'PREJUDICA?',
#        'ASPECTOS_PREJUDICADOS', 'VIVE_NO_BRASIL', 'ESTADO ONDE MORA',
#        'UF ONDE MORA', 'REGIAO ONDE MORA', 'MUDOU DE ESTADO?',
#        'REGIAO DE ORIGEM', 'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'COMPUTAÇÃO?', 'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NOVO NÍVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'NOVO NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior', 'GERAÇAO',
#        'Quanto tempo de experiência na área de dados você tem?',
#        'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
#        'Você está satisfeito na sua empresa atual?',
#        'Qual o principal motivo da sua insatisfação com a empresa atual?',
#        'Você participou de entrevistas de emprego nos últimos 6 meses?',
#        'Você pretende mudar de emprego nos próximos 6 meses?',
#        'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?',
#        'Atualmente qual a sua forma de trabalho?',
#        'Qual a forma de trabalho ideal para você?',
#        'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?',
#        'Sua empresa passu por Layoff em 2022?', 'Atuacao',
#        'Quais das linguagens listadas abaixo você utiliza no trabalho?',
#        'EM_BUSCA', 'Aberto a oportunidades'],
#       dtype='object')

# %% [markdown]
# #Correlação Contínua

# %%
##não pude fazer pois nao tenho a coluna salario

# %%
from scipy.stats import chi2_contingency

# %%
def cramer_coeficiente(coluna1, coluna2):
  tabela_cruzada = np.array(pd.crosstab(coluna1,coluna2))
  chi2 = chi2_contingency(tabela_cruzada)[0]
  soma = np.sum(tabela_cruzada)
  mini = min(tabela_cruzada.shape)-1
  cramer = np.sqrt(chi2/(soma*mini))
  return cramer

# %%
cramer_coeficiente(dados['GENERO'],dados['NIVEL DE ENSINO'])
# Out:
# np.float64(0.076119232802818)

# %%
tabela_cruzada = pd.crosstab(dados['GENERO'],dados['NIVEL DE ENSINO'])

# %%
tabela_cruzada
# Out:
# NIVEL DE ENSINO       Doutorado ou Phd  Estudante de Graduação  \
# GENERO
# Feminino                            57                     104
# Masculino                          134                     506
# Prefiro não informar                 0                       3
#
# NIVEL DE ENSINO       Graduação/Bacharelado  Mestrado  \
# GENERO
# Feminino                                365       133
# Masculino                              1138       386
# Prefiro não informar                      7         2
#
# NIVEL DE ENSINO       Não tenho graduação formal  Prefiro não informar  \
# GENERO
# Feminino                                      24                     3
# Masculino                                     86                     8
# Prefiro não informar                           0                     1
#
# NIVEL DE ENSINO       Pós-graduação
# GENERO
# Feminino                        372
# Masculino                       936
# Prefiro não informar              8

# %%
np.array(tabela_cruzada)
# Out:
# array([[  57,  104,  365,  133,   24,    3,  372],
#        [ 134,  506, 1138,  386,   86,    8,  936],
#        [   0,    3,    7,    2,    0,    1,    8]])

# %%
dados.to_csv('/content/drive/MyDrive/Analise de Dados PrograMaria/analise_dados.csv', index=False)
